# %%
import sys

# Install gdown if not already installed
if 'gdown' not in sys.modules:
    # !pip install gdown

# Google Drive folder ID
folder_id = '1FFvvjTX_EcXBPGPc5z2pG1y4U_nIaMvi'

# Download the folder using gdown
# This will download the contents into the current working directory in your Colab environment.
# gdown will create a directory with the same name as the folder on Google Drive.
# !gdown --folder {folder_id}
# Out:
# ...
# Retrieving folder contents
# Processing file 18yzScbnt15rticysJ4JBFhY5lKjT9UAA dataset_v5.7z.001
# Processing file 1QXT7vPmgqvaS-kiRvCCdiZDuMsO0Xgf- dataset_v5.7z.002
# Processing file 1OAJynnGuAprLk6q82y-KWH7STL384x2j dataset_v5.7z.003
# Processing file 1sChbR0vz_NRhtOR_BbOtFFdW_AGBE7ST dataset_v5.7z.004
# Processing file 1ZSaCs_q4jmEqyheTS24hlx5ALOh0VHHT dataset_v5.7z.005
# Processing file 11elxMN3ABdROFVNsiCfb-Drh2ImYDyqU dataset_v5.7z.006
# Processing file 15GKMEsLRCFQtmtQUxRATUAKeFMSqTHe6 dataset_v5.7z.007
# Processing file 1ejlTvyLuG9MqjWC5WtIjvdw3ebKhZ8sS dataset_v5.7z.008
# Processing file 12fj146c6qA8KN8NMJP9RUedx3uFawtvj dataset_v5.7z.009
# Processing file 1pxQ2Hys4ELqybN6OmuALEJtrrHk_-g8K dataset_v5.7z.010
# Processing file 1koMze2lTPSvVTV-p9yw81pgr0MqcnkrA dataset_v5.7z.011
# Processing file 1kpRJPQfEwTAk9KrOKStUAr_Az5a8fR9q dataset_v5.7z.012
# Processing file 17PyjDxlcN37BkwksBIyv3bcjcXUwRwDX dataset_v5.7z.013
# ...

# %%
# !unzip "/content/drone_localization_pack_with_ipynb (1).zip"
# Out:
# Archive:  /content/drone_localization_pack_with_ipynb (1).zip
#    creating: drone_localization_pack/dataset_v1/
#    creating: drone_localization_pack/weights/
#    creating: drone_localization_pack/results/
#    creating: drone_localization_pack/scripts/
#   inflating: drone_localization_pack/manual_results.json
#   inflating: drone_localization_pack/requirements_base.txt
#   inflating: drone_localization_pack/requirements_full.txt
#   inflating: drone_localization_pack/RUN_INSTRUCTIONS.md
#   inflating: drone_localization_pack/README.md
#   inflating: drone_localization_pack/Run_All.ipynb
#    creating: drone_localization_pack/dataset_v1/images/
#    creating: drone_localization_pack/dataset_v1/labels/
#    creating: drone_localization_pack/dataset_v1/images/train/
#    creating: drone_localization_pack/dataset_v1/images/val/
#    creating: drone_localization_pack/dataset_v1/images/test/
#   inflating: drone_localization_pack/dataset_v1/images/train/.gitkeep
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Merge `dataset_v1` folders

# %% [markdown]
# **Reasoning**:
# Now that the `dataset_v5.7z` archive has been extracted to `/content/extracted_dataset`, the next step is to merge its `dataset_v1` folder into the existing `drone_localization_pack/dataset_v1` directory. This is done using the `rsync` command, which is suitable for merging directory contents while handling existing files. The `-a` flag preserves file attributes, and `--update` ensures that only newer files are copied, effectively merging the directories by updating existing files and adding new ones.

# %%
print('Merging extracted dataset into drone_localization_pack...')
# !rsync -av --update /content/extracted_dataset/dataset_v1/ /content/drone_localization_pack/dataset_v1/
print('Dataset merging complete.')
# Out:
# Streaming output truncated to the last 5000 lines.
# labels/train/img_22617.txt
# labels/train/img_22618.txt
# labels/train/img_22621.txt
# labels/train/img_22622.txt
# labels/train/img_22623.txt
# labels/train/img_22624.txt
# labels/train/img_22625.txt
# labels/train/img_22627.txt
# labels/train/img_22628.txt
# labels/train/img_22629.txt
# labels/train/img_22630.txt
# labels/train/img_22631.txt
# labels/train/img_22633.txt
# labels/train/img_22634.txt
# labels/train/img_22635.txt
# labels/train/img_22636.txt
# labels/train/img_22637.txt
# labels/train/img_22642.txt
# labels/train/img_22643.txt
# labels/train/img_22644.txt
# labels/train/img_22645.txt
# labels/train/img_22647.txt
# labels/train/img_22649.txt
# labels/train/img_22650.txt
# labels/train/img_22651.txt
# labels/train/img_22652.txt
# labels/train/img_22653.txt
# labels/train/img_22654.txt
# labels/train/img_22655.txt
# labels/train/img_22656.txt
# labels/train/img_22657.txt
# labels/train/img_22659.txt
# ...

# %% [markdown]
# ## Remove temporary files

# %% [markdown]
# **Reasoning**:
# Now that the dataset has been merged into the working directory, the downloaded `.7z` archives and the temporary `extracted_dataset` folder are no longer needed. Removing them will free up disk space in the Colab environment.

# %%
print('Removing archive files...')
# !rm -rf /content/datasets/dataset_v5.7z*
print('Archive files removed.')

print('Removing extracted_dataset folder...')
# !rm -rf /content/extracted_dataset
print('extracted_dataset folder removed.')
# Out:
# Removing archive files...
# Archive files removed.
# Removing extracted_dataset folder...
# extracted_dataset folder removed.

# %% [markdown]
# ## Step 1: Dataset Audit
#
# This step runs `0_dataset_audit.py` to check the dataset's structure, CSV integrity, presence of NaN values, and missing files. The results will be saved in `results/dataset_audit/dataset_audit_summary.json`, `results/dataset_audit/dataset_audit_table.csv`, and `results/dataset_audit/dataset_audit_table.xlsx`.

# %%
# !python drone_localization_pack/scripts/0_dataset_audit.py --dataset_root drone_localization_pack/dataset_v1 --outdir drone_localization_pack/results/dataset_audit
# Out:
# [audit] split=train
# [audit] split=val
# [audit] split=test
# ✅ Done. Outputs saved to: /content/drone_localization_pack/results/dataset_audit

# %%
import json
from pathlib import Path

notebook_path = Path('/content/drone_localization_pack/Run_All.ipynb')

# Read the content of the notebook file
with open(notebook_path, 'r', encoding='utf-8') as f:
    notebook_content_str = f.read()

# Attempt to parse the content as JSON and then re-save it
try:
    notebook_json = json.loads(notebook_content_str)
    # Re-save the JSON content with standard formatting (indent=2)
    with open(notebook_path, 'w', encoding='utf-8') as f:
        json.dump(notebook_json, f, indent=2)
    print("Notebook 'Run_All.ipynb' has been reformatted and re-saved. Please try opening it as a notebook again.")
except json.JSONDecodeError as e:
    print(f"Error decoding JSON from notebook content: {e}")
    print("The notebook content might be malformed or corrupted beyond simple reformatting.")
# Out:
# {
#   "cells": [
#     {
#       "cell_type": "markdown",
#       "metadata": {},
#       "source": [
#         "# Drone Localization Pack — запуск (Google Colab / Windows)\n",
#         "\n",
#         "Этот ноутбук выполняет полный **последовательный прогон** пакета:\n",
#         "\n",
#         "1. Аудит датасета (`0_dataset_audit.py`)\n",
#         "2. Инференс + метрики:\n",
#         "   - ResNet18 (7D: `lat, lon, alt, x, y, z, w`)\n",
#         "   - ResNet34 (2D: `lat, lon`)\n",
#         "   - ResNeXt50_32x4d (3D: `lat, lon, alt`)\n",
#         "3. Сводная таблица результатов (`model_comparison.xlsx`) + добавление **ручных результатов YOLO11l-obb** из `manual_results.json`\n",
#         "\n",
#         "## Перед запуском\n",
#         "Проверь, что ты положил:\n",
#         "\n",
#         "- датасет в папку `dataset_v1/` (см. структуру в `RUN_INSTRUCTIONS.md`)\n",
#         "- веса моделей в `weights/`:\n",
#         "  - `weights/best_model_18_100_128_2.pth`\n",
# ...

# %% [markdown]
# # Task
# Install `p7zip-full` to extract the `dataset_v5.7z` archives and merge the extracted `dataset_v1` into the `drone_localization_pack/dataset_v1` directory.

# %% [markdown]
# ## Install 7-Zip
#
# ### Subtask:
# Install the p7zip-full package required to handle .7z archives.

# %% [markdown]
# **Reasoning**:
# The subtask requires installing the `p7zip-full` package to handle .7z archives. This involves first updating the package lists and then installing the specified package using `apt-get` commands.

# %%
# Update package lists
# !apt-get update

# Install p7zip-full
# !apt-get install -y p7zip-full
print("7-Zip (p7zip-full) installed successfully.")
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.8 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,302 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,629 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# ...

# %% [markdown]
# **Reasoning**:
# Now that `p7zip-full` is installed, the next step is to extract the downloaded multipart `.7z` archive. By running the extraction command on the first part of the archive (`dataset_v5.7z.001`), `7z` will automatically identify and use all subsequent parts to reconstruct the full dataset.

# %%
# !wc -l drone_localization_pack/dataset_v1/labels/test/_test_annotations.csv
# Out:
# 2 drone_localization_pack/dataset_v1/labels/test/_test_annotations.csv

# %%
print('Extracting dataset_v5.7z multipart archive...')
!7z x /content/datasets/dataset_v5.7z.001 -o/content/extracted_dataset
print('Extraction complete.')
# Out:
# Extracting dataset_v5.7z multipart archive...
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1048576000 bytes (1000 MiB)
#
# Extracting archive: /content/datasets/dataset_v5.7z.001
# --
# Path = /content/datasets/dataset_v5.7z.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 15
# Total Physical Size = 15431851563
# ----
# Path = dataset_v5.7z
# Size = 15431851563
# --
# Path = dataset_v5.7z
# Type = 7z
# Physical Size = 15431851563
# Headers Size = 447837
# Method = LZMA2:24
# Solid = +
# Blocks = 4
#
# Everything is Ok
#
# Folders: 9
# Files: 51287
# Size:       15664960971
# Compressed: 15431851563
# Extraction complete.

# %%
# !python drone_localization_pack/scripts/00_build_annotations_from_txt.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --image_ext .png \
  --splits train val test \
  --overwrite
# Out:
# [ok] split=train images=20513 rows_written=20513 missing_txt=0 -> drone_localization_pack/dataset_v1/labels/train/_train_annotations.csv
# [ok] split=val images=2564 rows_written=2564 missing_txt=0 -> drone_localization_pack/dataset_v1/labels/val/_val_annotations.csv
# [ok] split=test images=2565 rows_written=2565 missing_txt=0 -> drone_localization_pack/dataset_v1/labels/test/_test_annotations.csv

# %%
# !python drone_localization_pack/scripts/0_dataset_audit.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --outdir drone_localization_pack/results/dataset_audit
# Out:
# [audit] split=train
# [audit] split=val
# [audit] split=test
# ✅ Done. Outputs saved to: /content/drone_localization_pack/results/dataset_audit

# %%
# !python drone_localization_pack/scripts/1_eval_resnet18_7d.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --split test \
  --weights drone_localization_pack/weights/best_model_18_100_128_2.pth \
  --outdir drone_localization_pack/results/resnet18_7d \
  --batch_size 16
# Out:
# Device: cpu
# Images: drone_localization_pack/dataset_v1/images/test
# Labels: drone_localization_pack/dataset_v1/labels/test/_test_annotations.csv
# Weights: drone_localization_pack/weights/best_model_18_100_128_2.pth
# Traceback (most recent call last):
#   File "/content/drone_localization_pack/scripts/1_eval_resnet18_7d.py", line 217, in <module>
#     main()
#   File "/content/drone_localization_pack/scripts/1_eval_resnet18_7d.py", line 175, in main
#     model = load_model(weights, device)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drone_localization_pack/scripts/1_eval_resnet18_7d.py", line 76, in load_model
#     model.load_state_dict(state)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2629, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for ResNet18Regressor:
# ...

# %%
# %%bash
# python - <<'PY'
# from pathlib import Path
# p = Path("drone_localization_pack/scripts/1_eval_resnet18_auto.py")
# s = p.read_text(encoding="utf-8")
#
# needle = "def load_checkpoint_state(path: Path) -> Dict[str, torch.Tensor]:"
# if needle not in s:
#     raise SystemExit("Can't find insertion point in script")
#
# # Insert normalize function right after load_checkpoint_state (simple string surgery)
# insert = """
# def normalize_state_keys(state: Dict[str, torch.Tensor]) -> Dict[str, torch.Tensor]:
#     # Handles common training-time prefixes / naming differences:
#     # - DataParallel: "module."
#     # - Our old training code: "base_model." instead of "backbone."
#     new_state: Dict[str, torch.Tensor] = {}
#     for k, v in state.items():
#         if k.startswith("module."):
#             k = k[len("module."):]
#         if k.startswith("base_model."):
#             k = "backbone." + k[len("base_model."):]
#         new_state[k] = v
#     return new_state
# """
#
# # Add function after load_checkpoint_state definition block end.
# # We'll just add it after the first "raise ValueError" line in that function (safe).
# marker = "raise ValueError"
# idx = s.find(marker)
# if idx == -1:
#     raise SystemExit("Can't patch: no raise ValueError found")
#
# # find end of that function by searching next "\n\n" after idx
# end = s.find("\n\n", idx)
# if end == -1:
#     end = len(s)
#
# if "def normalize_state_keys" not in s:
#     s = s[:end] + "\n" + insert + s[end:]
#
# # Now ensure we call normalize_state_keys when loading
# s = s.replace(
#     "state = load_checkpoint_state(weights)",
#     "state = normalize_state_keys(load_checkpoint_state(weights))"
# )
#
# p.write_text(s, encoding="utf-8")
# print("✅ Patched:", p)
# PY
# Out:
# ✅ Patched: drone_localization_pack/scripts/1_eval_resnet18_auto.py

# %%
# !ls -F drone_localization_pack/
# Out:
# ls: cannot access 'drone_localization_pack/': No such file or directory

# %%
# !ls -F /content/
# Out:
# datasets/  drone_localization_pack_with_ipynb.zip  sample_data/

# %%
# !python drone_localization_pack/scripts/1_eval_resnet18_auto.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --split test \
  --weights drone_localization_pack/weights/best_model_18_100_128_2.pth \
  --outdir drone_localization_pack/results/resnet18_2d \
  --batch_size 32 \
  --device cpu
# Out:
# Device: cpu
# Images: drone_localization_pack/dataset_v1/images/test
# Labels: drone_localization_pack/dataset_v1/labels/test/_test_annotations.csv
# Weights: drone_localization_pack/weights/best_model_18_100_128_2.pth
# [info] checkpoint out_dim=2 -> using out_dim=2
# [info] target_cols=['lat', 'lon']
# ✅ Done.
# Predictions: drone_localization_pack/results/resnet18_2d/predictions_test.csv
# Report:      drone_localization_pack/results/resnet18_2d/report_test.csv
# Metrics:     drone_localization_pack/results/resnet18_2d/metrics_test.json

# %%
# %%bash
# cat > drone_localization_pack/scripts/2_eval_resnet34_auto.py <<'PY'
# from __future__ import annotations
#
# import argparse
# import json
# from pathlib import Path
# from typing import Dict, List, Tuple
#
# import numpy as np
# import pandas as pd
# import torch
# from torch import nn
# from torch.utils.data import Dataset, DataLoader
# from torchvision import models, transforms
# from PIL import Image
# import matplotlib.pyplot as plt
#
#
# IMAGENET_MEAN = (0.485, 0.456, 0.406)
# IMAGENET_STD = (0.229, 0.224, 0.225)
#
# DEFAULT_COLS_BY_D = {
#     2: ["lat", "lon"],
#     3: ["lat", "lon", "alt"],
#     7: ["lat", "lon", "alt", "x", "y", "z", "w"],
# }
#
#
# def ensure_dir(p: Path) -> Path:
#     p.mkdir(parents=True, exist_ok=True)
#     return p
#
#
# def load_checkpoint_state(path: Path) -> Dict[str, torch.Tensor]:
#     ckpt = torch.load(path, map_location="cpu")
#     if isinstance(ckpt, dict):
#         for k in ["state_dict", "model_state_dict", "model"]:
#             if k in ckpt and isinstance(ckpt[k], dict):
#                 return ckpt[k]
#         if all(isinstance(v, torch.Tensor) for v in ckpt.values()):
#             return ckpt
#     raise ValueError(f"Unsupported checkpoint format in {path}")
#
#
# def normalize_state_keys(state: Dict[str, torch.Tensor]) -> Dict[str, torch.Tensor]:
#     # Handles common prefixes / naming differences:
#     # - DataParallel: "module."
#     # - Some scripts: "backbone." instead of "base_model."
#     new_state: Dict[str, torch.Tensor] = {}
#     for k, v in state.items():
#         if k.startswith("module."):
#             k = k[len("module."):]
#         if k.startswith("backbone."):
#             k = "base_model." + k[len("backbone."):]
#         new_state[k] = v
#     return new_state
#
#
# def infer_output_dim_from_state(state: Dict[str, torch.Tensor]) -> int:
#     if "regressor.3.weight" in state:
#         return int(state["regressor.3.weight"].shape[0])
#
#     candidates: List[Tuple[int, str]] = []
#     for k, v in state.items():
#         if "regressor" in k and k.endswith(".weight") and isinstance(v, torch.Tensor) and v.ndim == 2:
#             parts = k.split(".")
#             if len(parts) >= 3 and parts[-1] == "weight":
#                 try:
#                     idx = int(parts[-2])
#                     candidates.append((idx, k))
#                 except Exception:
#                     pass
#     if candidates:
#         candidates.sort(key=lambda x: x[0])
#         last_key = candidates[-1][1]
#         return int(state[last_key].shape[0])
#
#     raise KeyError("Could not infer output dim from checkpoint.")
#
#
# class LabeledImages(Dataset):
#     def __init__(self, images_dir: Path, df: pd.DataFrame, target_cols: List[str], tfm):
#         self.images_dir = images_dir
#         self.df = df.reset_index(drop=True)
#         self.target_cols = target_cols
#         self.tfm = tfm
#
#     def __len__(self) -> int:
#         return len(self.df)
#
#     def __getitem__(self, idx: int):
#         row = self.df.iloc[idx]
#         fname = str(row["filename"])
#         img_path = self.images_dir / fname
#         img = Image.open(img_path).convert("RGB")
#         x = self.tfm(img)
#         y = torch.tensor([float(row[c]) for c in self.target_cols], dtype=torch.float32)
#         return x, y, fname
#
#
# class ResNet34Regressor(nn.Module):
#     def __init__(self, out_dim: int):
#         super().__init__()
#         try:
#             self.base_model = models.resnet34(weights=None)
#         except TypeError:
#             self.base_model = models.resnet34(pretrained=False)
#
#         num_ftrs = self.base_model.fc.in_features
#         self.base_model.fc = nn.Identity()
#
#         self.regressor = nn.Sequential(
#             nn.Linear(num_ftrs, 128),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(128, out_dim),
#         )
#
#     def forward(self, x: torch.Tensor) -> torch.Tensor:
#         feats = self.base_model(x)
#         return self.regressor(feats)
#
#
# def save_json(obj: dict, path: Path) -> None:
#     path.write_text(json.dumps(obj, indent=2, ensure_ascii=False), encoding="utf-8")
#
#
# def pos_error_stats(lat_true, lon_true, lat_pred, lon_pred) -> Dict[str, float]:
#     err = np.sqrt((lat_pred - lat_true) ** 2 + (lon_pred - lon_true) ** 2)
#     rmse = float(np.sqrt(np.mean(err ** 2)))
#     return {
#         "mean": float(np.mean(err)),
#         "median": float(np.median(err)),
#         "rmse": rmse,
#         "p90": float(np.percentile(err, 90)),
#         "p95": float(np.percentile(err, 95)),
#     }
#
#
# def main() -> None:
#     ap = argparse.ArgumentParser()
#     ap.add_argument("--dataset_root", type=str, required=True)
#     ap.add_argument("--split", type=str, default="test", choices=["train", "val", "test"])
#     ap.add_argument("--weights", type=str, required=True)
#     ap.add_argument("--outdir", type=str, required=True)
#     ap.add_argument("--batch_size", type=int, default=16)
#     ap.add_argument("--device", type=str, default="cpu", choices=["cpu", "cuda"])
#     ap.add_argument("--num_params", type=int, default=0, help="Override out_dim. If 0, infer from checkpoint.")
#     ap.add_argument("--target_cols", type=str, default="", help="Comma-separated override. Example: lat,lon")
#     args = ap.parse_args()
#
#     dataset_root = Path(args.dataset_root)
#     images_dir = dataset_root / "images" / args.split
#     labels_csv = dataset_root / "labels" / args.split / f"_{args.split}_annotations.csv"
#     weights = Path(args.weights)
#     outdir = ensure_dir(Path(args.outdir))
#
#     print(f"Device: {args.device}")
#     print(f"Images:  {images_dir}")
#     print(f"Labels:  {labels_csv}")
#     print(f"Weights: {weights}")
#
#     df = pd.read_csv(labels_csv)
#
#     state = normalize_state_keys(load_checkpoint_state(weights))
#     inferred_dim = infer_output_dim_from_state(state)
#     out_dim = args.num_params if args.num_params > 0 else inferred_dim
#
#     if args.target_cols.strip():
#         target_cols = [c.strip() for c in args.target_cols.split(",") if c.strip()]
#     else:
#         if out_dim not in DEFAULT_COLS_BY_D:
#             raise ValueError(f"Unsupported out_dim={out_dim}. Provide --target_cols explicitly.")
#         target_cols = DEFAULT_COLS_BY_D[out_dim]
#
#     for c in ["filename"] + target_cols:
#         if c not in df.columns:
#             raise KeyError(f"Missing column '{c}' in {labels_csv}. Columns={list(df.columns)}")
#
#     print(f"[info] checkpoint out_dim={inferred_dim} -> using out_dim={out_dim}")
#     print(f"[info] target_cols={target_cols}")
#
#     tfm = transforms.Compose(
#         [
#             transforms.Resize((224, 224)),
#             transforms.ToTensor(),
#             transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
#         ]
#     )
#
#     ds = LabeledImages(images_dir, df, target_cols, tfm)
#     dl = DataLoader(ds, batch_size=args.batch_size, shuffle=False, num_workers=2)
#
#     device = torch.device(args.device if (args.device == "cpu" or torch.cuda.is_available()) else "cpu")
#
#     model = ResNet34Regressor(out_dim)
#     model.load_state_dict(state, strict=True)
#     model.to(device)
#     model.eval()
#
#     preds_all = []
#     fnames_all = []
#     truths_all = []
#
#     with torch.no_grad():
#         for xb, yb, fnames in dl:
#             xb = xb.to(device)
#             yhat = model(xb).cpu().numpy()
#             preds_all.append(yhat)
#             truths_all.append(yb.numpy())
#             fnames_all.extend(list(fnames))
#
#     preds = np.concatenate(preds_all, axis=0)
#     truths = np.concatenate(truths_all, axis=0)
#
#     # predictions
#     pred_df = pd.DataFrame(preds, columns=[f"pred_{c}" for c in target_cols])
#     pred_df.insert(0, "filename", fnames_all)
#     pred_path = outdir / f"predictions_{args.split}.csv"
#     pred_df.to_csv(pred_path, index=False)
#
#     # report
#     gt_df = df[["filename"] + target_cols].copy()
#     rep = gt_df.merge(pred_df, on="filename", how="inner")
#     if len(rep) == 0:
#         raise ValueError("No matching filenames between predictions and ground truth.")
#
#     # metrics
#     metrics: Dict[str, float] = {}
#     for c in target_cols:
#         true = rep[c].to_numpy(dtype=float)
#         pred = rep[f"pred_{c}"].to_numpy(dtype=float)
#         abs_err = np.abs(pred - true)
#         sq_err = (pred - true) ** 2
#
#         rep[f"abs_err_{c}"] = abs_err
#         rep[f"sq_err_{c}"] = sq_err
#
#         metrics[f"MAE_{c}"] = float(np.mean(abs_err))
#         metrics[f"MSE_{c}"] = float(np.mean(sq_err))
#         metrics[f"RMSE_{c}"] = float(np.sqrt(np.mean(sq_err)))
#
#     metrics["MAE_mean"] = float(np.mean([metrics[f"MAE_{c}"] for c in target_cols]))
#     metrics["RMSE_mean"] = float(np.mean([metrics[f"RMSE_{c}"] for c in target_cols]))
#     metrics["n_images"] = int(len(rep))
#
#     # pos error for comparison (always computed if lat/lon present)
#     if "lat" in target_cols and "lon" in target_cols:
#         lat_true = rep["lat"].to_numpy(dtype=float)
#         lon_true = rep["lon"].to_numpy(dtype=float)
#         lat_pred = rep["pred_lat"].to_numpy(dtype=float)
#         lon_pred = rep["pred_lon"].to_numpy(dtype=float)
#         metrics["pos_error_2d_mean"] = float(np.mean(np.sqrt((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2)))
#         metrics["pos_error_2d_median"] = float(np.median(np.sqrt((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2)))
#         metrics["pos_error_2d_rmse"] = float(np.sqrt(np.mean(((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2))))
#         metrics["pos_error_2d_p90"] = float(np.percentile(np.sqrt((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2), 90))
#         metrics["pos_error_2d_p95"] = float(np.percentile(np.sqrt((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2), 95))
#
#     rep_path = outdir / f"report_{args.split}.csv"
#     rep.to_csv(rep_path, index=False)
#
#     metrics_path = outdir / f"metrics_{args.split}.json"
#     save_json(metrics, metrics_path)
#
#     # plots
#     for c in target_cols:
#         plt.figure()
#         plt.scatter(rep[c].to_numpy(dtype=float), rep[f"pred_{c}"].to_numpy(dtype=float), s=3)
#         plt.xlabel(f"true {c}")
#         plt.ylabel(f"pred {c}")
#         plt.title(f"ResNet34 ({out_dim}D) {args.split}: true vs pred ({c})")
#         plt.tight_layout()
#         plt.savefig(outdir / f"resnet34_{out_dim}d_{args.split}_scatter_{c}.png", dpi=200)
#         plt.close()
#
#         plt.figure()
#         plt.hist(rep[f"abs_err_{c}"].to_numpy(dtype=float), bins=60)
#         plt.xlabel(f"abs error {c}")
#         plt.ylabel("count")
#         plt.title(f"ResNet34 ({out_dim}D) {args.split}: abs error histogram ({c})")
#         plt.tight_layout()
#         plt.savefig(outdir / f"resnet34_{out_dim}d_{args.split}_hist_{c}.png", dpi=200)
#         plt.close()
#
#     print("✅ Done.")
#     print(f"Predictions: {pred_path}")
#     print(f"Report:      {rep_path}")
#     print(f"Metrics:     {metrics_path}")
#
#
# if __name__ == "__main__":
#     main()
# PY

# %%
# !python drone_localization_pack/scripts/2_eval_resnet34_auto.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --split test \
  --weights drone_localization_pack/weights/best_model_34_100_128.pth \
  --outdir drone_localization_pack/results/resnet34_7d \
  --batch_size 32 \
  --device cuda
# Out:
# Device: cuda
# Images:  drone_localization_pack/dataset_v1/images/test
# Labels:  drone_localization_pack/dataset_v1/labels/test/_test_annotations.csv
# Weights: drone_localization_pack/weights/best_model_34_100_128.pth
# [info] checkpoint out_dim=7 -> using out_dim=7
# [info] target_cols=['lat', 'lon', 'alt', 'x', 'y', 'z', 'w']
# ✅ Done.
# Predictions: drone_localization_pack/results/resnet34_7d/predictions_test.csv
# Report:      drone_localization_pack/results/resnet34_7d/report_test.csv
# Metrics:     drone_localization_pack/results/resnet34_7d/metrics_test.json

# %%
# !python drone_localization_pack/scripts/3_eval_resnext50_3d.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --split test \
  --weights drone_localization_pack/weights/best_geo_model_new.pth \
  --outdir drone_localization_pack/results/resnext50_3d \
  --batch_size 64 \
  --num_workers 2 \
  --device cuda
# Out:
# Fitting StandardScaler on train + val labels (lat/lon/alt)...
# Scaler fitted.
# Device: cuda
# Traceback (most recent call last):
#   File "/content/drone_localization_pack/scripts/3_eval_resnext50_3d.py", line 249, in <module>
#     main()
#   File "/content/drone_localization_pack/scripts/3_eval_resnext50_3d.py", line 210, in main
#     state = load_state_dict_safely(weights, device)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drone_localization_pack/scripts/3_eval_resnext50_3d.py", line 92, in load_state_dict_safely
#     obj = torch.load(weights_path, map_location=device)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1521, in load
#     return _load(
#            ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 2122, in _load
#     result = unpickler.load()
#              ^^^^^^^^^^^^^^^^
# ...

# %%
# !ls -la drone_localization_pack/weights
# Out:
# total 8
# drwxrwxr-x 2 root root 4096 Dec 13 23:53 .
# drwxr-xr-x 6 root root 4096 Jan 20 18:03 ..

# %%
# %%bash
# cat > drone_localization_pack/scripts/1_eval_resnet18_auto.py <<'PY'
# from __future__ import annotations
#
# import argparse
# import json
# from pathlib import Path
# from typing import Dict, List, Tuple
#
# import numpy as np
# import pandas as pd
# import torch
# from torch import nn
# from torch.utils.data import Dataset, DataLoader
# from torchvision import models, transforms
# from PIL import Image
# import matplotlib.pyplot as plt
#
#
# IMAGENET_MEAN = (0.485, 0.456, 0.406)
# IMAGENET_STD = (0.229, 0.224, 0.225)
#
# DEFAULT_COLS_BY_D = {
#     2: ["lat", "lon"],
#     3: ["lat", "lon", "alt"],
#     7: ["lat", "lon", "alt", "x", "y", "z", "w"],
# }
#
#
# def ensure_dir(p: Path) -> Path:
#     p.mkdir(parents=True, exist_ok=True)
#     return p
#
#
# def load_checkpoint_state(path: Path) -> Dict[str, torch.Tensor]:
#     ckpt = torch.load(path, map_location="cpu")
#     if isinstance(ckpt, dict):
#         for k in ["state_dict", "model_state_dict", "model"]:
#             if k in ckpt and isinstance(ckpt[k], dict):
#                 return ckpt[k]
#         # sometimes it's already a state_dict dict
#         if all(isinstance(v, torch.Tensor) for v in ckpt.values()):
#             return ckpt
#     raise ValueError(f"Unsupported checkpoint format in {path}")
#
#
# def infer_output_dim_from_state(state: Dict[str, torch.Tensor]) -> int:
#     # common key in our regressor head:
#     # regressor.3.weight -> shape [out_dim, 128]
#     if "regressor.3.weight" in state:
#         return int(state["regressor.3.weight"].shape[0])
#
#     # fallback: find last linear in regressor
#     candidates: List[Tuple[int, str]] = []
#     for k, v in state.items():
#         if "regressor" in k and k.endswith(".weight") and isinstance(v, torch.Tensor) and v.ndim == 2:
#             # try to extract layer index from "regressor.{i}.weight"
#             parts = k.split(".")
#             if len(parts) >= 3 and parts[-1] == "weight":
#                 try:
#                     idx = int(parts[-2])
#                     candidates.append((idx, k))
#                 except Exception:
#                     pass
#     if candidates:
#         candidates.sort(key=lambda x: x[0])
#         last_key = candidates[-1][1]
#         return int(state[last_key].shape[0])
#
#     raise KeyError("Could not infer output dim from checkpoint (no regressor.*.weight found).")
#
#
# class LabeledImages(Dataset):
#     def __init__(self, images_dir: Path, df: pd.DataFrame, target_cols: List[str], tfm):
#         self.images_dir = images_dir
#         self.df = df.reset_index(drop=True)
#         self.target_cols = target_cols
#         self.tfm = tfm
#
#     def __len__(self) -> int:
#         return len(self.df)
#
#     def __getitem__(self, idx: int):
#         row = self.df.iloc[idx]
#         fname = str(row["filename"])
#         img_path = self.images_dir / fname
#         img = Image.open(img_path).convert("RGB")
#         x = self.tfm(img)
#
#         y = torch.tensor([float(row[c]) for c in self.target_cols], dtype=torch.float32)
#         return x, y, fname
#
#
# def build_model(out_dim: int) -> nn.Module:
#     backbone = models.resnet18(weights=None)
#     num_ftrs = backbone.fc.in_features
#     backbone.fc = nn.Identity()
#
#     regressor = nn.Sequential(
#         nn.Linear(num_ftrs, 128),
#         nn.ReLU(),
#         nn.Dropout(0.2),
#         nn.Linear(128, out_dim),
#     )
#     model = nn.Module()
#     model.backbone = backbone
#     model.regressor = regressor
#
#     def forward(x):
#         feats = model.backbone(x)
#         return model.regressor(feats)
#
#     model.forward = forward  # type: ignore
#     return model
#
#
# def save_json(obj: dict, path: Path) -> None:
#     path.write_text(json.dumps(obj, indent=2, ensure_ascii=False), encoding="utf-8")
#
#
# def main() -> None:
#     ap = argparse.ArgumentParser()
#     ap.add_argument("--dataset_root", type=str, required=True)
#     ap.add_argument("--split", type=str, default="test", choices=["train", "val", "test"])
#     ap.add_argument("--weights", type=str, required=True)
#     ap.add_argument("--outdir", type=str, required=True)
#     ap.add_argument("--batch_size", type=int, default=16)
#     ap.add_argument("--device", type=str, default="cpu", choices=["cpu", "cuda"])
#     ap.add_argument("--num_params", type=int, default=0, help="Override output dim. If 0, infer from checkpoint.")
#     ap.add_argument("--target_cols", type=str, default="", help="Comma-separated target cols override.")
#     args = ap.parse_args()
#
#     dataset_root = Path(args.dataset_root)
#     images_dir = dataset_root / "images" / args.split
#     labels_csv = dataset_root / "labels" / args.split / f"_{args.split}_annotations.csv"
#     weights = Path(args.weights)
#     outdir = ensure_dir(Path(args.outdir))
#
#     print(f"Device: {args.device}")
#     print(f"Images: {images_dir}")
#     print(f"Labels: {labels_csv}")
#     print(f"Weights: {weights}")
#
#     df = pd.read_csv(labels_csv)
#
#     state = load_checkpoint_state(weights)
#     inferred_dim = infer_output_dim_from_state(state)
#     out_dim = args.num_params if args.num_params > 0 else inferred_dim
#
#     if args.target_cols.strip():
#         target_cols = [c.strip() for c in args.target_cols.split(",") if c.strip()]
#     else:
#         if out_dim not in DEFAULT_COLS_BY_D:
#             raise ValueError(
#                 f"Unsupported out_dim={out_dim}. Provide --target_cols explicitly."
#             )
#         target_cols = DEFAULT_COLS_BY_D[out_dim]
#
#     for c in ["filename"] + target_cols:
#         if c not in df.columns:
#             raise KeyError(f"Missing column '{c}' in {labels_csv}. Columns: {list(df.columns)}")
#
#     print(f"[info] checkpoint out_dim={inferred_dim} -> using out_dim={out_dim}")
#     print(f"[info] target_cols={target_cols}")
#
#     tfm = transforms.Compose(
#         [
#             transforms.Resize((224, 224)),
#             transforms.ToTensor(),
#             transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
#         ]
#     )
#
#     ds = LabeledImages(images_dir, df, target_cols, tfm)
#     dl = DataLoader(
#         ds,
#         batch_size=args.batch_size,
#         shuffle=False,
#         num_workers=2,
#         pin_memory=(args.device == "cuda"),
#     )
#
#     device = torch.device(args.device if (args.device == "cpu" or torch.cuda.is_available()) else "cpu")
#
#     model = build_model(out_dim)
#     model.load_state_dict(state, strict=True)
#     model.to(device)
#     model.eval()
#
#     preds_all = []
#     fnames_all = []
#     truths_all = []
#
#     with torch.no_grad():
#         for xb, yb, fnames in dl:
#             xb = xb.to(device)
#             yhat = model(xb).cpu().numpy()
#             preds_all.append(yhat)
#             truths_all.append(yb.numpy())
#             fnames_all.extend(list(fnames))
#
#     preds = np.concatenate(preds_all, axis=0)
#     truths = np.concatenate(truths_all, axis=0)
#
#     # predictions file
#     pred_df = pd.DataFrame(preds, columns=[f"pred_{c}" for c in target_cols])
#     pred_df.insert(0, "filename", fnames_all)
#     pred_path = outdir / f"predictions_{args.split}.csv"
#     pred_df.to_csv(pred_path, index=False)
#
#     # report file
#     gt_cols = ["filename"] + target_cols
#     gt_df = df[gt_cols].copy()
#     rep = gt_df.merge(pred_df, on="filename", how="inner")
#
#     # errors + metrics
#     metrics: Dict[str, float] = {}
#     abs_err_cols = []
#     sq_err_cols = []
#
#     for i, c in enumerate(target_cols):
#         true = rep[c].to_numpy(dtype=float)
#         pred = rep[f"pred_{c}"].to_numpy(dtype=float)
#         abs_err = np.abs(pred - true)
#         sq_err = (pred - true) ** 2
#
#         rep[f"abs_err_{c}"] = abs_err
#         rep[f"sq_err_{c}"] = sq_err
#         abs_err_cols.append(f"abs_err_{c}")
#         sq_err_cols.append(f"sq_err_{c}")
#
#         metrics[f"MAE_{c}"] = float(np.mean(abs_err))
#         metrics[f"MSE_{c}"] = float(np.mean(sq_err))
#         metrics[f"RMSE_{c}"] = float(np.sqrt(np.mean(sq_err)))
#
#     metrics["MAE_mean"] = float(np.mean([metrics[f"MAE_{c}"] for c in target_cols]))
#     metrics["RMSE_mean"] = float(np.mean([metrics[f"RMSE_{c}"] for c in target_cols]))
#     metrics["n_images"] = int(len(rep))
#
#     rep_path = outdir / f"report_{args.split}.csv"
#     rep.to_csv(rep_path, index=False)
#
#     metrics_path = outdir / f"metrics_{args.split}.json"
#     save_json(metrics, metrics_path)
#
#     # Simple plots
#     for c in target_cols:
#         plt.figure()
#         plt.scatter(rep[c].to_numpy(dtype=float), rep[f"pred_{c}"].to_numpy(dtype=float), s=3)
#         plt.xlabel(f"true {c}")
#         plt.ylabel(f"pred {c}")
#         plt.title(f"ResNet18 ({out_dim}D) {args.split}: true vs pred ({c})")
#         plt.tight_layout()
#         plt.savefig(outdir / f"resnet18_{out_dim}d_{args.split}_scatter_{c}.png", dpi=200)
#         plt.close()
#
#         plt.figure()
#         plt.hist(rep[f"abs_err_{c}"].to_numpy(dtype=float), bins=60)
#         plt.xlabel(f"abs error {c}")
#         plt.ylabel("count")
#         plt.title(f"ResNet18 ({out_dim}D) {args.split}: abs error histogram ({c})")
#         plt.tight_layout()
#         plt.savefig(outdir / f"resnet18_{out_dim}d_{args.split}_hist_{c}.png", dpi=200)
#         plt.close()
#
#     print("✅ Done.")
#     print(f"Predictions: {pred_path}")
#     print(f"Report:      {rep_path}")
#     print(f"Metrics:     {metrics_path}")
#
#
# if __name__ == "__main__":
#     main()
# PY

# %%
# %%bash
# python - <<'PY'
# from pathlib import Path
# p = Path("drone_localization_pack/scripts/1_eval_resnet18_auto.py")
# s = p.read_text(encoding="utf-8")
#
# needle = "def load_checkpoint_state(path: Path) -> Dict[str, torch.Tensor]:"
# if needle not in s:
#     raise SystemExit("Can't find insertion point in script")
#
# # Insert normalize function right after load_checkpoint_state (simple string surgery)
# insert = """
# def normalize_state_keys(state: Dict[str, torch.Tensor]) -> Dict[str, torch.Tensor]:
#     # Handles common training-time prefixes / naming differences:
#     # - DataParallel: "module."
#     # - Our old training code: "base_model." instead of "backbone."
#     new_state: Dict[str, torch.Tensor] = {}
#     for k, v in state.items():
#         if k.startswith("module."):
#             k = k[len("module."):]
#         if k.startswith("base_model."):
#             k = "backbone." + k[len("base_model."):]
#         new_state[k] = v
#     return new_state
# """
#
# # Add function after load_checkpoint_state definition block end.
# # We'll just add it after the first "raise ValueError" line in that function (safe).
# marker = "raise ValueError"
# idx = s.find(marker)
# if idx == -1:
#     raise SystemExit("Can't patch: no raise ValueError found")
#
# # find end of that function by searching next "\n\n" after idx
# end = s.find("\n\n", idx)
# if end == -1:
#     end = len(s)
#
# if "def normalize_state_keys" not in s:
#     s = s[:end] + "\n" + insert + s[end:]
#
# # Now ensure we call normalize_state_keys when loading
# s = s.replace(
#     "state = load_checkpoint_state(weights)",
#     "state = normalize_state_keys(load_checkpoint_state(weights))"
# )
#
# p.write_text(s, encoding="utf-8")
# print("✅ Patched:", p)
# PY
# Out:
# ✅ Patched: drone_localization_pack/scripts/1_eval_resnet18_auto.py

# %%
# !python drone_localization_pack/scripts/1_eval_resnet18_auto.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --split test \
  --weights drone_localization_pack/weights/best_model_18_100_128_2.pth \
  --outdir drone_localization_pack/results/resnet18_2d \
  --batch_size 32 \
  --device cuda
# Out:
# Device: cuda
# Images: drone_localization_pack/dataset_v1/images/test
# Labels: drone_localization_pack/dataset_v1/labels/test/_test_annotations.csv
# Weights: drone_localization_pack/weights/best_model_18_100_128_2.pth
# [info] checkpoint out_dim=2 -> using out_dim=2
# [info] target_cols=['lat', 'lon']
# ✅ Done.
# Predictions: drone_localization_pack/results/resnet18_2d/predictions_test.csv
# Report:      drone_localization_pack/results/resnet18_2d/report_test.csv
# Metrics:     drone_localization_pack/results/resnet18_2d/metrics_test.json

# %%
# %%bash
# cat > drone_localization_pack/scripts/2_eval_resnet34_auto.py <<'PY'
# from __future__ import annotations
#
# import argparse
# import json
# from pathlib import Path
# from typing import Dict, List, Tuple
#
# import numpy as np
# import pandas as pd
# import torch
# from torch import nn
# from torch.utils.data import Dataset, DataLoader
# from torchvision import models, transforms
# from PIL import Image
# import matplotlib.pyplot as plt
#
#
# IMAGENET_MEAN = (0.485, 0.456, 0.406)
# IMAGENET_STD = (0.229, 0.224, 0.225)
#
# DEFAULT_COLS_BY_D = {
#     2: ["lat", "lon"],
#     3: ["lat", "lon", "alt"],
#     7: ["lat", "lon", "alt", "x", "y", "z", "w"],
# }
#
#
# def ensure_dir(p: Path) -> Path:
#     p.mkdir(parents=True, exist_ok=True)
#     return p
#
#
# def load_checkpoint_state(path: Path) -> Dict[str, torch.Tensor]:
#     ckpt = torch.load(path, map_location="cpu")
#     if isinstance(ckpt, dict):
#         for k in ["state_dict", "model_state_dict", "model"]:
#             if k in ckpt and isinstance(ckpt[k], dict):
#                 return ckpt[k]
#         if all(isinstance(v, torch.Tensor) for v in ckpt.values()):
#             return ckpt
#     raise ValueError(f"Unsupported checkpoint format in {path}")
#
#
# def normalize_state_keys(state: Dict[str, torch.Tensor]) -> Dict[str, torch.Tensor]:
#     # Handles common prefixes / naming differences:
#     # - DataParallel: "module."
#     # - Some scripts: "backbone." instead of "base_model."
#     new_state: Dict[str, torch.Tensor] = {}
#     for k, v in state.items():
#         if k.startswith("module."):
#             k = k[len("module."):]
#         if k.startswith("backbone."):
#             k = "base_model." + k[len("backbone."):]
#         new_state[k] = v
#     return new_state
#
#
# def infer_output_dim_from_state(state: Dict[str, torch.Tensor]) -> int:
#     if "regressor.3.weight" in state:
#         return int(state["regressor.3.weight"].shape[0])
#
#     candidates: List[Tuple[int, str]] = []
#     for k, v in state.items():
#         if "regressor" in k and k.endswith(".weight") and isinstance(v, torch.Tensor) and v.ndim == 2:
#             parts = k.split(".")
#             if len(parts) >= 3 and parts[-1] == "weight":
#                 try:
#                     idx = int(parts[-2])
#                     candidates.append((idx, k))
#                 except Exception:
#                     pass
#     if candidates:
#         candidates.sort(key=lambda x: x[0])
#         last_key = candidates[-1][1]
#         return int(state[last_key].shape[0])
#
#     raise KeyError("Could not infer output dim from checkpoint.")
#
#
# class LabeledImages(Dataset):
#     def __init__(self, images_dir: Path, df: pd.DataFrame, target_cols: List[str], tfm):
#         self.images_dir = images_dir
#         self.df = df.reset_index(drop=True)
#         self.target_cols = target_cols
#         self.tfm = tfm
#
#     def __len__(self) -> int:
#         return len(self.df)
#
#     def __getitem__(self, idx: int):
#         row = self.df.iloc[idx]
#         fname = str(row["filename"])
#         img_path = self.images_dir / fname
#         img = Image.open(img_path).convert("RGB")
#         x = self.tfm(img)
#         y = torch.tensor([float(row[c]) for c in self.target_cols], dtype=torch.float32)
#         return x, y, fname
#
#
# class ResNet34Regressor(nn.Module):
#     def __init__(self, out_dim: int):
#         super().__init__()
#         try:
#             self.base_model = models.resnet34(weights=None)
#         except TypeError:
#             self.base_model = models.resnet34(pretrained=False)
#
#         num_ftrs = self.base_model.fc.in_features
#         self.base_model.fc = nn.Identity()
#
#         self.regressor = nn.Sequential(
#             nn.Linear(num_ftrs, 128),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(128, out_dim),
#         )
#
#     def forward(self, x: torch.Tensor) -> torch.Tensor:
#         feats = self.base_model(x)
#         return self.regressor(feats)
#
#
# def save_json(obj: dict, path: Path) -> None:
#     path.write_text(json.dumps(obj, indent=2, ensure_ascii=False), encoding="utf-8")
#
#
# def pos_error_stats(lat_true, lon_true, lat_pred, lon_pred) -> Dict[str, float]:
#     err = np.sqrt((lat_pred - lat_true) ** 2 + (lon_pred - lon_true) ** 2)
#     rmse = float(np.sqrt(np.mean(err ** 2)))
#     return {
#         "mean": float(np.mean(err)),
#         "median": float(np.median(err)),
#         "rmse": rmse,
#         "p90": float(np.percentile(err, 90)),
#         "p95": float(np.percentile(err, 95)),
#     }
#
#
# def main() -> None:
#     ap = argparse.ArgumentParser()
#     ap.add_argument("--dataset_root", type=str, required=True)
#     ap.add_argument("--split", type=str, default="test", choices=["train", "val", "test"])
#     ap.add_argument("--weights", type=str, required=True)
#     ap.add_argument("--outdir", type=str, required=True)
#     ap.add_argument("--batch_size", type=int, default=16)
#     ap.add_argument("--device", type=str, default="cpu", choices=["cpu", "cuda"])
#     ap.add_argument("--num_params", type=int, default=0, help="Override out_dim. If 0, infer from checkpoint.")
#     ap.add_argument("--target_cols", type=str, default="", help="Comma-separated override. Example: lat,lon")
#     args = ap.parse_args()
#
#     dataset_root = Path(args.dataset_root)
#     images_dir = dataset_root / "images" / args.split
#     labels_csv = dataset_root / "labels" / args.split / f"_{args.split}_annotations.csv"
#     weights = Path(args.weights)
#     outdir = ensure_dir(Path(args.outdir))
#
#     print(f"Device: {args.device}")
#     print(f"Images:  {images_dir}")
#     print(f"Labels:  {labels_csv}")
#     print(f"Weights: {weights}")
#
#     df = pd.read_csv(labels_csv)
#
#     state = normalize_state_keys(load_checkpoint_state(weights))
#     inferred_dim = infer_output_dim_from_state(state)
#     out_dim = args.num_params if args.num_params > 0 else inferred_dim
#
#     if args.target_cols.strip():
#         target_cols = [c.strip() for c in args.target_cols.split(",") if c.strip()]
#     else:
#         if out_dim not in DEFAULT_COLS_BY_D:
#             raise ValueError(f"Unsupported out_dim={out_dim}. Provide --target_cols explicitly.")
#         target_cols = DEFAULT_COLS_BY_D[out_dim]
#
#     for c in ["filename"] + target_cols:
#         if c not in df.columns:
#             raise KeyError(f"Missing column '{c}' in {labels_csv}. Columns={list(df.columns)}")
#
#     print(f"[info] checkpoint out_dim={inferred_dim} -> using out_dim={out_dim}")
#     print(f"[info] target_cols={target_cols}")
#
#     tfm = transforms.Compose(
#         [
#             transforms.Resize((224, 224)),
#             transforms.ToTensor(),
#             transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
#         ]
#     )
#
#     ds = LabeledImages(images_dir, df, target_cols, tfm)
#     dl = DataLoader(ds, batch_size=args.batch_size, shuffle=False, num_workers=2)
#
#     device = torch.device(args.device if (args.device == "cpu" or torch.cuda.is_available()) else "cpu")
#
#     model = ResNet34Regressor(out_dim)
#     model.load_state_dict(state, strict=True)
#     model.to(device)
#     model.eval()
#
#     preds_all = []
#     fnames_all = []
#     truths_all = []
#
#     with torch.no_grad():
#         for xb, yb, fnames in dl:
#             xb = xb.to(device)
#             yhat = model(xb).cpu().numpy()
#             preds_all.append(yhat)
#             truths_all.append(yb.numpy())
#             fnames_all.extend(list(fnames))
#
#     preds = np.concatenate(preds_all, axis=0)
#     truths = np.concatenate(truths_all, axis=0)
#
#     # predictions
#     pred_df = pd.DataFrame(preds, columns=[f"pred_{c}" for c in target_cols])
#     pred_df.insert(0, "filename", fnames_all)
#     pred_path = outdir / f"predictions_{args.split}.csv"
#     pred_df.to_csv(pred_path, index=False)
#
#     # report
#     gt_df = df[["filename"] + target_cols].copy()
#     rep = gt_df.merge(pred_df, on="filename", how="inner")
#     if len(rep) == 0:
#         raise ValueError("No matching filenames between predictions and ground truth.")
#
#     # metrics
#     metrics: Dict[str, float] = {}
#     for c in target_cols:
#         true = rep[c].to_numpy(dtype=float)
#         pred = rep[f"pred_{c}"].to_numpy(dtype=float)
#         abs_err = np.abs(pred - true)
#         sq_err = (pred - true) ** 2
#
#         rep[f"abs_err_{c}"] = abs_err
#         rep[f"sq_err_{c}"] = sq_err
#
#         metrics[f"MAE_{c}"] = float(np.mean(abs_err))
#         metrics[f"MSE_{c}"] = float(np.mean(sq_err))
#         metrics[f"RMSE_{c}"] = float(np.sqrt(np.mean(sq_err)))
#
#     metrics["MAE_mean"] = float(np.mean([metrics[f"MAE_{c}"] for c in target_cols]))
#     metrics["RMSE_mean"] = float(np.mean([metrics[f"RMSE_{c}"] for c in target_cols]))
#     metrics["n_images"] = int(len(rep))
#
#     # pos error for comparison (always computed if lat/lon present)
#     if "lat" in target_cols and "lon" in target_cols:
#         lat_true = rep["lat"].to_numpy(dtype=float)
#         lon_true = rep["lon"].to_numpy(dtype=float)
#         lat_pred = rep["pred_lat"].to_numpy(dtype=float)
#         lon_pred = rep["pred_lon"].to_numpy(dtype=float)
#         metrics["pos_error_2d_mean"] = float(np.mean(np.sqrt((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2)))
#         metrics["pos_error_2d_median"] = float(np.median(np.sqrt((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2)))
#         metrics["pos_error_2d_rmse"] = float(np.sqrt(np.mean(((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2))))
#         metrics["pos_error_2d_p90"] = float(np.percentile(np.sqrt((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2), 90))
#         metrics["pos_error_2d_p95"] = float(np.percentile(np.sqrt((lat_pred-lat_true)**2 + (lon_pred-lon_true)**2), 95))
#
#     rep_path = outdir / f"report_{args.split}.csv"
#     rep.to_csv(rep_path, index=False)
#
#     metrics_path = outdir / f"metrics_{args.split}.json"
#     save_json(metrics, metrics_path)
#
#     # plots
#     for c in target_cols:
#         plt.figure()
#         plt.scatter(rep[c].to_numpy(dtype=float), rep[f"pred_{c}"].to_numpy(dtype=float), s=3)
#         plt.xlabel(f"true {c}")
#         plt.ylabel(f"pred {c}")
#         plt.title(f"ResNet34 ({out_dim}D) {args.split}: true vs pred ({c})")
#         plt.tight_layout()
#         plt.savefig(outdir / f"resnet34_{out_dim}d_{args.split}_scatter_{c}.png", dpi=200)
#         plt.close()
#
#         plt.figure()
#         plt.hist(rep[f"abs_err_{c}"].to_numpy(dtype=float), bins=60)
#         plt.xlabel(f"abs error {c}")
#         plt.ylabel("count")
#         plt.title(f"ResNet34 ({out_dim}D) {args.split}: abs error histogram ({c})")
#         plt.tight_layout()
#         plt.savefig(outdir / f"resnet34_{out_dim}d_{args.split}_hist_{c}.png", dpi=200)
#         plt.close()
#
#     print("✅ Done.")
#     print(f"Predictions: {pred_path}")
#     print(f"Report:      {rep_path}")
#     print(f"Metrics:     {metrics_path}")
#
#
# if __name__ == "__main__":
#     main()
# PY

# %%
# !python drone_localization_pack/scripts/2_eval_resnet34_auto.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --split test \
  --weights drone_localization_pack/weights/best_model_34_100_128.pth \
  --outdir drone_localization_pack/results/resnet34_7d \
  --batch_size 32 \
  --device cuda
# Out:
# Device: cuda
# Images:  drone_localization_pack/dataset_v1/images/test
# Labels:  drone_localization_pack/dataset_v1/labels/test/_test_annotations.csv
# Weights: drone_localization_pack/weights/best_model_34_100_128.pth
# [info] checkpoint out_dim=7 -> using out_dim=7
# [info] target_cols=['lat', 'lon', 'alt', 'x', 'y', 'z', 'w']
# ✅ Done.
# Predictions: drone_localization_pack/results/resnet34_7d/predictions_test.csv
# Report:      drone_localization_pack/results/resnet34_7d/report_test.csv
# Metrics:     drone_localization_pack/results/resnet34_7d/metrics_test.json

# %%
# !python drone_localization_pack/scripts/3_eval_resnext50_3d.py \
  --dataset_root drone_localization_pack/dataset_v1 \
  --split test \
  --weights drone_localization_pack/weights/best_geo_model_new.pth \
  --outdir drone_localization_pack/results/resnext50_3d \
  --batch_size 16 \
  --num_workers 2 \
  --device cuda
# Out:
# Fitting StandardScaler on train + val labels (lat/lon/alt)...
# Scaler fitted.
# Device: cuda
# ✅ Saved predictions: drone_localization_pack/results/resnext50_3d/predictions_test.csv
# ✅ Saved report: drone_localization_pack/results/resnext50_3d/report_test.csv
# ✅ Saved metrics: drone_localization_pack/results/resnext50_3d/metrics_test.json
#
# Summary:
#   n_samples: 2565
#   total MAE: 1.453987
#   pos_error_mean: 3.417 (same units as lat/lon)

# %%
# !python drone_localization_pack/scripts/4_aggregate_results.py \
  --results_root drone_localization_pack/results \
  --manual drone_localization_pack/manual_results.json \
  --out_xlsx drone_localization_pack/results/model_comparison.xlsx \
  --out_csv drone_localization_pack/results/model_comparison.csv
# Out:
# /content/drone_localization_pack/scripts/4_aggregate_results.py:89: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_combined = pd.concat([df_auto, df_manual], ignore_index=True, sort=False)
# ✅ Saved Excel: /content/drone_localization_pack/results/model_comparison.xlsx
# ✅ Saved CSV:  /content/drone_localization_pack/results/model_comparison.csv
# Auto metrics files found: 3

# %%
# %%bash
# cat > drone_localization_pack/scripts/4_aggregate_results_v2.py <<'PY'
# from __future__ import annotations
#
# import argparse
# import json
# from pathlib import Path
# from typing import Any, Dict, List, Optional
#
# import numpy as np
# import pandas as pd
#
#
# def _read_json(p: Path) -> Any:
#     return json.loads(p.read_text(encoding="utf-8"))
#
#
# def _infer_model_name_from_path(p: Path) -> str:
#     s = str(p).lower()
#     if "resnet18" in s:
#         return "ResNet18"
#     if "resnet34" in s:
#         return "ResNet34"
#     if "resnext" in s:
#         return "ResNeXt50_32x4d"
#     return p.parent.name
#
#
# def _infer_out_dim_from_flat_keys(d: Dict[str, Any]) -> Optional[int]:
#     # Detect by presence of MAE_* keys
#     if "MAE_w" in d and "MAE_z" in d and "MAE_x" in d and "MAE_y" in d:
#         return 7
#     if "MAE_alt" in d and "MAE_lon" in d and "MAE_lat" in d and "MAE_w" not in d:
#         return 3
#     if "MAE_lat" in d and "MAE_lon" in d and "MAE_alt" not in d:
#         return 2
#     return None
#
#
# def _outputs_by_dim(dim: int) -> str:
#     if dim == 2:
#         return "lat, lon"
#     if dim == 3:
#         return "lat, lon, alt"
#     if dim == 7:
#         return "lat, lon, alt, x, y, z, w"
#     return ""
#
#
# def _family_from_name(name: str) -> str:
#     if name.startswith("ResNet"):
#         return "ResNet"
#     if name.startswith("ResNeXt"):
#         return "ResNeXt"
#     if "YOLO" in name:
#         return "YOLO"
#     if "MobileNet" in name:
#         return "MobileNet"
#     return ""
#
#
# def _pos_stats_from_series(err: np.ndarray) -> Dict[str, float]:
#     err = np.asarray(err, dtype=float)
#     return {
#         "mean": float(np.mean(err)),
#         "median": float(np.median(err)),
#         "rmse": float(np.sqrt(np.mean(err ** 2))),
#         "p90": float(np.percentile(err, 90)),
#         "p95": float(np.percentile(err, 95)),
#         "p99": float(np.percentile(err, 99)),
#         "min": float(np.min(err)),
#         "max": float(np.max(err)),
#     }
#
#
# def _try_compute_pos_error_from_report(report_csv: Path) -> Optional[Dict[str, float]]:
#     if not report_csv.exists():
#         return None
#     df = pd.read_csv(report_csv)
#
#     # Two common layouts:
#     # A) lat, lon, pred_lat, pred_lon
#     if {"lat", "lon", "pred_lat", "pred_lon"}.issubset(df.columns):
#         lat_true = df["lat"].to_numpy(dtype=float)
#         lon_true = df["lon"].to_numpy(dtype=float)
#         lat_pred = df["pred_lat"].to_numpy(dtype=float)
#         lon_pred = df["pred_lon"].to_numpy(dtype=float)
#         err = np.sqrt((lat_pred - lat_true) ** 2 + (lon_pred - lon_true) ** 2)
#         return _pos_stats_from_series(err)
#
#     # B) lat_true, lon_true, lat_pred, lon_pred
#     if {"lat_true", "lon_true", "lat_pred", "lon_pred"}.issubset(df.columns):
#         lat_true = df["lat_true"].to_numpy(dtype=float)
#         lon_true = df["lon_true"].to_numpy(dtype=float)
#         lat_pred = df["lat_pred"].to_numpy(dtype=float)
#         lon_pred = df["lon_pred"].to_numpy(dtype=float)
#         err = np.sqrt((lat_pred - lat_true) ** 2 + (lon_pred - lon_true) ** 2)
#         return _pos_stats_from_series(err)
#
#     return None
#
#
# def _parse_metrics_file(metrics_path: Path) -> Dict[str, Any]:
#     d = _read_json(metrics_path)
#     row: Dict[str, Any] = {}
#     row["source"] = str(metrics_path)
#
#     # Base fields
#     row["model_name"] = d.get("model_name") or _infer_model_name_from_path(metrics_path)
#     row["task"] = d.get("task") or ""
#     row["split"] = d.get("split") or "test"
#     row["weights"] = d.get("weights") or ""
#     row["device"] = d.get("device") or ""
#     row["scaler_used"] = d.get("scaler_used") if "scaler_used" in d else ""
#
#     # n_images
#     n = d.get("n_samples")
#     if n is None:
#         n = d.get("n_images")
#     if n is None:
#         n = d.get("n_matched")
#     row["n_images"] = int(n) if n is not None else ""
#
#     # Determine out_dim
#     out_dim = None
#     if "per_param" in d and isinstance(d["per_param"], dict):
#         # ResNeXt-like structure
#         mae = d["per_param"].get("MAE", {})
#         if isinstance(mae, dict):
#             if set(mae.keys()) >= {"lat", "lon", "alt"}:
#                 out_dim = 3
#     if out_dim is None:
#         out_dim = _infer_out_dim_from_flat_keys(d)
#     if out_dim is None:
#         # fallback by presence of total/per_param
#         out_dim = 3 if "per_param" in d else 2
#
#     row["outputs"] = _outputs_by_dim(out_dim)
#     row["family"] = _family_from_name(row["model_name"])
#
#     # totals
#     if "total" in d and isinstance(d["total"], dict):
#         row["total_MAE"] = d["total"].get("MAE", "")
#         row["total_MSE"] = d["total"].get("MSE", "")
#         row["total_RMSE"] = d["total"].get("RMSE", "")
#     else:
#         # flat format: MAE_mean / RMSE_mean exist
#         row["total_MAE"] = d.get("MAE_mean", "")
#         row["total_RMSE"] = d.get("RMSE_mean", "")
#         # total_MSE: average of all MSE_* we have
#         mse_keys = [k for k in d.keys() if k.startswith("MSE_") and k not in ("MSE_mean",)]
#         if mse_keys:
#             row["total_MSE"] = float(np.mean([float(d[k]) for k in mse_keys]))
#         else:
#             row["total_MSE"] = ""
#
#     # per-param MAE
#     def _get_mae(name: str) -> Any:
#         if "per_param" in d and isinstance(d["per_param"], dict):
#             mae = d["per_param"].get("MAE", {})
#             if isinstance(mae, dict) and name in mae:
#                 return mae[name]
#         return d.get(f"MAE_{name}", "")
#
#     row["MAE_lat"] = _get_mae("lat")
#     row["MAE_lon"] = _get_mae("lon")
#     row["MAE_alt"] = _get_mae("alt") if out_dim >= 3 else ""
#
#     # pos_error
#     if "pos_error_2d" in d and isinstance(d["pos_error_2d"], dict):
#         pe = d["pos_error_2d"]
#         row["pos_error_mean"] = pe.get("mean", "")
#         row["pos_error_median"] = pe.get("median", "")
#         row["pos_error_rmse"] = pe.get("rmse", "")
#         row["pos_error_p90"] = pe.get("p90", "")
#         row["pos_error_p95"] = pe.get("p95", "")
#         row["pos_error_p99"] = pe.get("p99", "")
#         row["pos_error_min"] = pe.get("min", "")
#         row["pos_error_max"] = pe.get("max", "")
#     elif "pos_error_2d_mean" in d:
#         # flat format from ResNet34 auto
#         row["pos_error_mean"] = d.get("pos_error_2d_mean", "")
#         row["pos_error_median"] = d.get("pos_error_2d_median", "")
#         row["pos_error_rmse"] = d.get("pos_error_2d_rmse", "")
#         row["pos_error_p90"] = d.get("pos_error_2d_p90", "")
#         row["pos_error_p95"] = d.get("pos_error_2d_p95", "")
#         row["pos_error_p99"] = d.get("pos_error_2d_p99", "")
#         row["pos_error_min"] = ""
#         row["pos_error_max"] = ""
#     else:
#         # Try compute from report CSV (useful for ResNet18 2D auto)
#         report_csv = metrics_path.parent / f"report_{row['split']}.csv"
#         pe = _try_compute_pos_error_from_report(report_csv)
#         if pe is not None:
#             row["pos_error_mean"] = pe["mean"]
#             row["pos_error_median"] = pe["median"]
#             row["pos_error_rmse"] = pe["rmse"]
#             row["pos_error_p90"] = pe["p90"]
#             row["pos_error_p95"] = pe["p95"]
#             row["pos_error_p99"] = pe["p99"]
#             row["pos_error_min"] = pe["min"]
#             row["pos_error_max"] = pe["max"]
#         else:
#             row["pos_error_mean"] = ""
#             row["pos_error_median"] = ""
#             row["pos_error_rmse"] = ""
#             row["pos_error_p90"] = ""
#             row["pos_error_p95"] = ""
#             row["pos_error_p99"] = ""
#             row["pos_error_min"] = ""
#             row["pos_error_max"] = ""
#
#     # if task empty — fill from out_dim
#     if not row["task"]:
#         if out_dim == 2:
#             row["task"] = "2D regression (lat,lon)"
#         elif out_dim == 3:
#             row["task"] = "3D regression (lat,lon,alt)"
#         else:
#             row["task"] = "7D regression (lat,lon,alt,x,y,z,w)"
#
#     return row
#
#
# def _load_manual(manual_path: Path) -> pd.DataFrame:
#     if not manual_path.exists():
#         return pd.DataFrame()
#     d = _read_json(manual_path)
#     if isinstance(d, list):
#         return pd.DataFrame(d)
#     if isinstance(d, dict):
#         for key in ["rows", "manual_results", "data", "items"]:
#             if key in d and isinstance(d[key], list):
#                 return pd.DataFrame(d[key])
#         # fallback: single dict
#         return pd.DataFrame([d])
#     return pd.DataFrame()
#
#
# def main() -> None:
#     ap = argparse.ArgumentParser()
#     ap.add_argument("--results_root", type=str, required=True)
#     ap.add_argument("--manual", type=str, default="")
#     ap.add_argument("--out_xlsx", type=str, required=True)
#     ap.add_argument("--out_csv", type=str, required=True)
#     args = ap.parse_args()
#
#     results_root = Path(args.results_root)
#     metrics_files = sorted(results_root.rglob("metrics_test.json"))
#
#     rows: List[Dict[str, Any]] = []
#     for mp in metrics_files:
#         try:
#             rows.append(_parse_metrics_file(mp))
#         except Exception as e:
#             print(f"[warn] skip {mp}: {e}")
#
#     auto_df = pd.DataFrame(rows)
#
#     # Stable column order
#     cols = [
#         "model_name","task","split","weights","device","scaler_used","n_images",
#         "total_MAE","total_MSE","total_RMSE","source",
#         "MAE_lat","MAE_lon","MAE_alt",
#         "pos_error_mean","pos_error_median","pos_error_rmse","pos_error_p90","pos_error_p95","pos_error_p99","pos_error_min","pos_error_max",
#         "family","outputs",
#     ]
#     for c in cols:
#         if c not in auto_df.columns:
#             auto_df[c] = ""
#     auto_df = auto_df[cols].sort_values(["model_name","task"]).reset_index(drop=True)
#
#     manual_df = _load_manual(Path(args.manual)) if args.manual else pd.DataFrame()
#
#     # Combined: just concat (align columns where possible)
#     combined_df = pd.concat([auto_df, manual_df], ignore_index=True, sort=False)
#
#     out_xlsx = Path(args.out_xlsx)
#     out_csv = Path(args.out_csv)
#     out_xlsx.parent.mkdir(parents=True, exist_ok=True)
#
#     with pd.ExcelWriter(out_xlsx, engine="openpyxl") as w:
#         auto_df.to_excel(w, index=False, sheet_name="auto_results")
#         if not manual_df.empty:
#             manual_df.to_excel(w, index=False, sheet_name="manual_results")
#         combined_df.to_excel(w, index=False, sheet_name="combined")
#
#     combined_df.to_csv(out_csv, index=False)
#     print(f"✅ Saved: {out_xlsx}")
#     print(f"✅ Saved: {out_csv}")
#     print(f"[info] auto rows: {len(auto_df)}  manual rows: {len(manual_df)}  combined: {len(combined_df)}")
#
#
# if __name__ == "__main__":
#     main()
# PY

# %%
# !python drone_localization_pack/scripts/4_aggregate_results_v2.py \
  --results_root drone_localization_pack/results \
  --manual drone_localization_pack/manual_results.json \
  --out_xlsx drone_localization_pack/results/model_comparison_v2.xlsx \
  --out_csv drone_localization_pack/results/model_comparison_v2.csv
# Out:
# ✅ Saved: drone_localization_pack/results/model_comparison_v2.xlsx
# ✅ Saved: drone_localization_pack/results/model_comparison_v2.csv
# [info] auto rows: 3  manual rows: 1  combined: 4

# %%
# %%bash
# python - <<'PY'
# from pathlib import Path
#
# p = Path("drone_localization_pack/scripts/4_aggregate_results_v2.py")
# s = p.read_text(encoding="utf-8")
#
# old = 'for key in ["rows", "manual_results", "data", "items"]'
# new = 'for key in ["rows", "manual_results", "manual_entries", "data", "items", "entries"]'
#
# if old not in s:
#     raise SystemExit("Не нашёл место для патча. Скажи — я дам альтернативный патч по regex.")
# s = s.replace(old, new)
#
# p.write_text(s, encoding="utf-8")
# print("✅ Patched _load_manual(): added 'manual_entries'")
# PY
# Out:
# ✅ Patched _load_manual(): added 'manual_entries'

# %%
# !python drone_localization_pack/scripts/4_aggregate_results_v2.py \
  --results_root drone_localization_pack/results \
  --manual drone_localization_pack/manual_results.json \
  --out_xlsx drone_localization_pack/results/model_comparison_v3.xlsx \
  --out_csv drone_localization_pack/results/model_comparison_v3.csv
# Out:
# /content/drone_localization_pack/scripts/4_aggregate_results_v2.py:274: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat([auto_df, manual_df], ignore_index=True, sort=False)
# ✅ Saved: drone_localization_pack/results/model_comparison_v3.xlsx
# ✅ Saved: drone_localization_pack/results/model_comparison_v3.csv
# [info] auto rows: 3  manual rows: 4  combined: 7

# %%
# !python - <<'PY'
import pandas as pd
p="drone_localization_pack/results/model_comparison_v3.xlsx"
xls=pd.ExcelFile(p)
print("sheets:", xls.sheet_names)
dfm=pd.read_excel(p, sheet_name="manual_results")
print("manual rows:", len(dfm))
print(dfm[["model_name","task","fps_linq"]].head(10))
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# sheets: ['auto_results', 'manual_results', 'combined']
# manual rows: 4
#                     model_name  \
# 0                  YOLO11l-obb
# 1     ResNet34 (LinQ FPS only)
# 2     ResNet50 (LinQ FPS only)
# 3  MobileNetV2 (LinQ FPS only)
#
#                                                 task  fps_linq
# 0  detector-baseline (OBB) -> derived localizatio...        20
# 1                                      fps benchmark       443
# 2                                      fps benchmark       430
# 3                                      fps benchmark       142
